# %%
import pandas as pd
import numpy as nm

# %%
dataset=pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
from DSunivariateclass import univariate
quan_columns,qual_columns=univariate.quan_qual(dataset)
print(quan_columns)
print(qual_columns)
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
dataset_describe=univariate.datasetdescribe(dataset,quan_columns)
dataset_describe
# Out:
#                            sl_no       ssc_p       hsc_p   degree_p  \
# MEAN                       108.0   67.303395   66.333163  66.370186
# MEDIAN                     108.0        67.0        65.0       66.0
# MODE                           1        62.0        63.0       65.0
# Q1                          54.5        60.6        60.9       61.0
# Q1:25%                      54.5        60.6        60.9       61.0
# Q2:50%                     108.0        67.0        65.0       66.0
# Q3:75%                     161.5        75.7        73.0       72.0
# Q4:100%                    215.0        89.4        97.7       91.0
# IQR                        107.0        15.1        12.1       11.0
# 1.5Rule                    160.5       22.65       18.15       16.5
# Lesser_Outlier_Range      -106.0       37.95       42.75       44.5
# Greater_Outlier_Range      322.0       98.35       91.15       88.5
# Min                            1       40.89        37.0       50.0
# ...

# %%
#identify the outlier
lesser_outlier,greater_outlier=univariate.identifyoutlier(dataset_describe,quan_columns)
print("lesser_outlier_columns:",lesser_outlier)
print("greater_outlier_columns:",greater_outlier)
# Out:
# lesser_outlier_columns: ['hsc_p']
# greater_outlier_columns: ['hsc_p', 'degree_p', 'salary']

# %%
#replacing the outlier with the defined range
univariate.replaceoutlier(dataset,dataset_describe,lesser_outlier,greater_outlier)

# %%
dataset_describe=univariate.datasetdescribe(dataset,quan_columns)
dataset_describe
# Out:
#                            sl_no       ssc_p       hsc_p   degree_p  \
# MEAN                       108.0   67.303395   66.334744  66.358558
# MEDIAN                     108.0        67.0        65.0       66.0
# MODE                           1        62.0        63.0       65.0
# Q1                          54.5        60.6        60.9       61.0
# Q1:25%                      54.5        60.6        60.9       61.0
# Q2:50%                     108.0        67.0        65.0       66.0
# Q3:75%                     161.5        75.7        73.0       72.0
# Q4:100%                    215.0        89.4       91.15       88.5
# IQR                        107.0        15.1        12.1       11.0
# 1.5Rule                    160.5       22.65       18.15       16.5
# Lesser_Outlier_Range      -106.0       37.95       42.75       44.5
# Greater_Outlier_Range      322.0       98.35       91.15       88.5
# Min                            1       40.89       42.75       50.0
# ...

# %%
univariate.freqtable(dataset,quan_columns)
# Out:
# sl_no
#      Unique_values  Frequency  Relative_frequency  Cumsum
# 0                1          1                   1       1
# 1                2          1                   1       2
# 2                3          1                   1       3
# 3                4          1                   1       4
# 4                5          1                   1       5
# ..             ...        ...                 ...     ...
# 210            211          1                   1     211
# 211            212          1                   1     212
# 212            213          1                   1     213
# 213            214          1                   1     214
# 214            215          1                   1     215
#
# [215 rows x 4 columns]
# ssc_p
#      Unique_values  Frequency  Relative_frequency  Cumsum
# 0            62.00         11                  11      11
# 1            63.00         10                  10      21
# ...
